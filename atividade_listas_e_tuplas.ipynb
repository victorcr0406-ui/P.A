# %% [markdown]
# <a href="https://colab.research.google.com/github/victorcr0406-ui/P.A/blob/main/atividade_listas_e_tuplas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
LISTAS

# %%
Frutas = ['maçã','banana','laranja','morango']
print(Frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
nomes = ['Rebeca','Guilherme','Melissa','Kyara']
print(nomes[0])
print(nomes[1])
print(nomes[3])
# Out:
# Rebeca
# Guilherme
# Kyara

# %%
cores = ['vermelho','azul','verde']
print(cores)
cores[1]= 'amarelo'
print(cores)
# Out:
# ['vermelho', 'azul', 'verde']
# ['vermelho', 'amarelo', 'verde']

# %%
alunos = ['nicolas','wendel','pyetra']
print(alunos)
alunos.append('petros')
print(alunos)
# Out:
# ['nicolas', 'wendel', 'pyetra']
# ['nicolas', 'wendel', 'pyetra', 'petros']

# %%
animais = ['cachorro','gato','coelho','passarinho']
print(animais)
animais.remove('coelho')
print(animais)
# Out:
# ['cachorro', 'gato', 'coelho', 'passarinho']
# ['cachorro', 'gato', 'passarinho']

# %% [markdown]
# TUPLAS

# %%
meses = ('janeiro','fevereiro','março','abril')
print(meses)
# Out:
# ('janeiro', 'fevereiro', 'março', 'abril')

# %%
numeros = ('10','20','30','40','50')
print(numeros[0])
print(numeros[2])
print(numeros[4])
# Out:
# 10
# 30
# 50

# %%
# Dados do aluno

nome = ('Victor')
idade = ('15 anos')
curso = ('Informatica para internet')

print(nome)
print(idade)
print(curso)
# Out:
# Victor
# 15 anos
# Informatica para internet

# %%
cores = ('vermelho','azul','verde')
print(cores)
cores[1]= 'amarelo'
print(cores)

# o código da erro exatamente na linha que eu tento alterar algo na tupla
# Out:
# ('vermelho', 'azul', 'verde')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6350/2981695528.py in <cell line: 0>()
#       1 cores = ('vermelho','azul','verde')
#       2 print(cores)
# ----> 3 cores[1]= 'amarelo'
#       4 print(cores)
#
# TypeError: 'tuple' object does not support item assignment

# %%
numeros = ('2','4','2','6','2','8','10')
print(numeros.count('2'))
# Out:
# 3
