# %% [markdown]
# <a href="https://colab.research.google.com/github/victorcr0406-ui/P.A/blob/main/ATIVIDADES%201%20BIM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Digite o primeiro número: "))
b = int(input("Digite o segundo número: "))

soma = a + b

print("Soma:", soma)
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 2
# Soma: 4

# %%
a = float(input("Digite o primeiro número: "))
b = float(input("Digite o segundo número: "))

resultado = a - b

print("Subtração:", resultado)
# Out:
# Digite o primeiro número: 10
# Digite o segundo número: 5
# Subtração: 5.0

# %%
a = float(input("Digite o primeiro número: "))
b = float(input("Digite o segundo número: "))

resultado = a * b

print("Multiplicação:", resultado)
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 2
# Multiplicação: 4.0

# %%
a = float(input("Digite o primeiro número: "))
b = float(input("Digite o segundo número: "))

if b != 0:
    resultado = a / b
    print("Divisão:", resultado)
else:
    print("Erro: divisão por zero não é permitida.")
# Out:
# Digite o primeiro número: 10
# Digite o segundo número: 2
# Divisão: 5.0

# %%
a = float(input("Digite o primeiro número: "))
b = float(input("Digite o segundo número: "))
c = float(input("Digite o terceiro número: "))

media = (a + b + c) / 3

print("Média:", media)
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 2
# Digite o terceiro número: 2
# Média: 2.0

# %%
num = int(input("Digite um número inteiro: "))

dobro = num * 2
metade = num / 2
resto = num % 3

print("Dobro:", dobro)
print("Metade:", metade)
print("Resto da divisão por 3:", resto)
# Out:
# Digite um número inteiro: 10
# Dobro: 20
# Metade: 5.0
# Resto da divisão por 3: 1

# %%
c = float(input("Digite a temperatura em Celsius: "))

f = (c * 9/5) + 32

print("Temperatura em Fahrenheit:", f)
# Out:
# Digite a temperatura em Celsius: 20
# Temperatura em Fahrenheit: 68.0

# %%
salario = float(input("Digite o salário: "))

novo_salario = salario * 1.10

print("Novo salário:", novo_salario)
# Out:
# Digite o salário: 1000
# Novo salário: 1100.0

# %%
base = float(input("Digite a base: "))
altura = float(input("Digite a altura: "))

area = base * altura

print("Área:", area)
# Out:
# Digite a base: 6
# Digite a altura: 4
# Área: 24.0

# %%
distancia = float(input("Digite a distância (km): "))
litros = float(input("Digite o combustível gasto (litros): "))

if litros != 0:
    consumo = distancia / litros
    print("Consumo médio:", consumo, "km/l")
else:
    print("Erro: combustível não pode ser zero.")
# Out:
# Digite a distância (km): 20
# Digite o combustível gasto (litros): 40
# Consumo médio: 0.5 km/l
