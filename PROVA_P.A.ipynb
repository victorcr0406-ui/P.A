# %% [markdown]
# <a href="https://colab.research.google.com/github/victorcr0406-ui/P.A/blob/main/PROVA_P.A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = int(input("Digite um número: "))

if numero % 2 == 0:
    print("O número é par.")
else:
    print("O número é ímpar.")

# %%
numero_1 = float(input("Digite o primeiro número: "))
numero_2 = float(input("Digite o segundo número: "))

if numero_1 > numero_2:
    print("O primeiro número é maior.")
elif numero_2 > numero_1:
    print("O segundo número é maior.")
else:
    print("Os números são iguais.")
# Out:
# Digite o primeiro número: 10
# Digite o segundo número: 12
# O segundo número é maior.

# %%
nota = float(input("Digite a nota do aluno: "))

if nota >= 7:
    print("aprovado")
elif nota >= 5 and nota < 7:
    print("recuperação")
else:
    print("reprovado")
# Out:
# Digite a nota do aluno: 7
# aprovado

# %%
idade = int(input("Digite a idade: "))

if 0 <= idade <= 10:
    print("Criança")
elif 11 <= idade <= 17:
    print("Adolescente")
elif 18 <= idade <= 59:
    print("Adulto")
else:
    print("Idoso")
# Out:
# Digite a idade: 20
# Adulto

# %%
senha = "123456"

senha_digitada = input("Digite a senha: ")

if senha_digitada == senha:
    print("Acesso permitido")
else:
    print("Acesso negado")
# Out:
# Digite a senha: 1234
# Acesso negado

# %%
dia = int(input("Digite o dia da semana (1-7): "))

if dia == 1:
    print("Domingo")
elif dia == 2:
    print("Segunda-feira")
elif dia == 3:
    print("Terça-feira")
elif dia == 4:
    print("Quarta-feira")
elif dia == 5:
    print("Quinta-feira")
elif dia == 6:
    print("Sexta-feira")
elif dia == 7:
    print("Sábado")
# Out:
# Digite o dia da semana (1-7): 6
# Sexta-feira

# %%
valor = float(input("Digite o valor da compra: "))

if valor >=100:
  desconto = valor * 0.90
  print("O valor da compra com desconto é: R$", desconto)
elif valor >= 50:
  print("O valor da compra com desconto é: R$", valor)
  else
# Out:
# Digite o valor da compra: 100
# O valor da compra com desconto é: R$ 90.0

# %%
# escrever um programa calculadora simples

# entrada

a = int(input("digite o primeiro numero: "))
b = int(input("digite o segundo numero: "))

# processamento

soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b
div_int = a // b # usar barras duplas "//" para divisões inteiras
resto = a % b # o simbolo de % é igual ao resto da divisão


# saída


print("--------------------CALCULADORA SIMPLES---------------")
print("---------------------------SOMA-----------------------")
print(f"o resultado da soma de {a} mais {b} é igual a:{soma}")
print("                                                       ")
print("---------------------------SUBTRACAO----------------------------")
print(f"o resultado da subtracao de {a} menos {b} é igual a:{subtracao}")
print("")
print("------------------       ---MULTIPLICACAO-----------------------")
print(f"o resultado da multiplicacao de {a} vezes {b} é igual a:{multiplicacao}")
print("")
print("---------------------------DIVISAO-----------------------")
print(f"o resultado da divisao de {a} dividido {b} é igual a:{divisao}")
print("---------------------------DIVSAO INTEIRA----------------")
print(f"o resutado da divisão de {a} dividido {b} é igual a:")
# Out:
# digite o primeiro numero: 109
# digite o segundo numero: 10
# --------------------CALCULADORA SIMPLES---------------
# ---------------------------SOMA-----------------------
# o resultado da soma de 109 mais 10 é igual a:119
#
# ---------------------------SUBTRACAO----------------------------
# o resultado da subtracao de 109 menos 10 é igual a:99
#
# ------------------       ---MULTIPLICACAO-----------------------
# o resultado da multiplicacao de 109 vezes 10 é igual a:1090
#
# ---------------------------DIVISAO-----------------------
# o resultado da divisao de 109 dividido 10 é igual a:10.9
# ---------------------------DIVSAO INTEIRA----------------
# o resutado da divisão de 109 dividido 10 é igual a:

# %%
ano =int(input("Digite o ano: "))

if (ano %4 ==0 and ano % 100 != 0) or (ano % 400 == 0):
  print("O ano é bissexto")
else:
  print("O ano não é bissexto")
# Out:
# Digite o ano: 2025
# O ano não é bissexto
